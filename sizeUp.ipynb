# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
aLevel = pd.read_csv("/Users/sadiqkhawaja/Desktop/Brackets/WhereamI/sizeUps/AQA-A-LEVEL-STATS-JUN-2023.csv")
aLevel
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                Results statistics – June 2023 exams        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3   These figures are provisional, pending enquiri...        NaN        NaN
# 4       For further information, email eos@aqa.org.uk        NaN        NaN
# ..                                                ...        ...        ...
# 57                         Version 1.0 17 August 2023        NaN        NaN
# 58  Copyright © AQA and its licensors. All rights ...        NaN        NaN
# 59  AQA Education (AQA) is a registered charity (n...        NaN        NaN
# 60  Our registered address is AQA, Devas Street, M...        NaN        NaN
# 61                                                NaN        NaN        NaN
#
# ...

# %%
n = 8
aLevel.drop(index = aLevel.index[:n],inplace=True)
aLevel.drop(aLevel.tail(8).index, inplace=True)
aLevel
# Out:
#             Unnamed: 0                           Unnamed: 1 Unnamed: 2  \
# 8   Specification Code                  Specification Title      Entry
# 9                  NaN                                  NaN        NaN
# 10                7127                       ACCOUNTING ADV       2314
# 11                7205         ART & DESIGN ADV (3D DESIGN)        956
# 12                7201  ART & DESIGN ADV (ART, CRAFT & DES)       3026
# 13                7202          ART & DESIGN ADV (FINE ART)       7102
# 14                7203      ART & DESIGN ADV (GRAPHIC COMM)       2887
# 15                7206       ART & DESIGN ADV (PHOTOGRAPHY)       5269
# 16                7204    ART & DESIGN ADV (TEXTILE DESIGN)       1924
# 17                7637                          BENGALI ADV         0~
# 18                7677                  BIBLICAL HEBREW ADV         53
# 19                7402                          BIOLOGY ADV      38254
# ...

# %%
aLevelResults = aLevel
aLevelResults.drop(index = aLevel.index[:2], inplace = True)
aLevelResults.drop(aLevelResults.columns[0], axis = 1, inplace = True)
aLevelResults
# Out:
#                              Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 10                       ACCOUNTING ADV       2314        1.8       13.8
# 11         ART & DESIGN ADV (3D DESIGN)        956       10.5       26.2
# 12  ART & DESIGN ADV (ART, CRAFT & DES)       3026       14.2       31.0
# 13          ART & DESIGN ADV (FINE ART)       7102       15.1       34.8
# 14      ART & DESIGN ADV (GRAPHIC COMM)       2887       12.0       31.0
# 15       ART & DESIGN ADV (PHOTOGRAPHY)       5269        9.7       22.3
# 16    ART & DESIGN ADV (TEXTILE DESIGN)       1924       13.0       34.5
# 17                          BENGALI ADV         0~         0~         0~
# 18                  BIBLICAL HEBREW ADV         53       60.4       75.5
# 19                          BIOLOGY ADV      38254        8.4       25.5
# 20                         BUSINESS ADV      17307        3.6       14.8
# 21                        CHEMISTRY ADV      26440        8.7       31.0
# ...

# %%
aLevelResults.drop(aLevelResults.columns[9:22], axis = 1, inplace = True)
aLevelResults
# Out:
#                              Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 10                       ACCOUNTING ADV       2314        1.8       13.8
# 11         ART & DESIGN ADV (3D DESIGN)        956       10.5       26.2
# 12  ART & DESIGN ADV (ART, CRAFT & DES)       3026       14.2       31.0
# 13          ART & DESIGN ADV (FINE ART)       7102       15.1       34.8
# 14      ART & DESIGN ADV (GRAPHIC COMM)       2887       12.0       31.0
# 15       ART & DESIGN ADV (PHOTOGRAPHY)       5269        9.7       22.3
# 16    ART & DESIGN ADV (TEXTILE DESIGN)       1924       13.0       34.5
# 17                          BENGALI ADV         0~         0~         0~
# 18                  BIBLICAL HEBREW ADV         53       60.4       75.5
# 19                          BIOLOGY ADV      38254        8.4       25.5
# 20                         BUSINESS ADV      17307        3.6       14.8
# 21                        CHEMISTRY ADV      26440        8.7       31.0
# ...

# %%
accounting = aLevelResults.iloc[0].values[2:]
accounting
# Out:
# array(['1.8', '13.8', '34.8', '58.9', '79.2', '93.7', '100.0'],
#       dtype=object)

# %%
accountingIndividual = []
for i in range(0,len(accounting)):
    accounting[i] = float(accounting[i])
    if i != 0:
        accountingIndividual.append(float(format(accounting[i] - accounting[i-1],".2f")))
    else:
        accountingIndividual.append(float(format(accounting[i],".2f")))
accountingIndividual
# Out:
# [1.8, 12.0, 21.0, 24.1, 20.3, 14.5, 6.3]

# %%
grades = ["A*","A","B","C","D","E","U"]

# %%
plt.bar(grades, accountingIndividual,)
# Out:
# <BarContainer object of 7 artists>
